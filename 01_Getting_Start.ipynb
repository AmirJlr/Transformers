# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirJlr/Transformers/blob/master/01_Getting_Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with Language Models and Tokenizers

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 111.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 115.9 MB/s eta 0:00:00
# ...

# %%
from transformers import BertTokenizer 
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
text = 'Using Transformers is easy!'
tokenizer(text)
# Out:
# {'input_ids': [101, 2478, 19081, 2003, 3733, 999, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
text = 'Using Transformers is easy'
tokenizer(text)
# Out:
# {'input_ids': [101, 2478, 19081, 2003, 3733, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1]}

# %% [markdown]
# # pipeline

# %%
from transformers import pipeline

# Allocate a pipeline for sentiment-analysis
classifier = pipeline('sentiment-analysis')
classifier('We are very happy to introduce pipeline to the transformers repository.')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'POSITIVE', 'score': 0.9996980428695679}]

# %%
unmasker = pipeline('fill-mask', model='bert-base-uncased')
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
import pandas as pd
pd.DataFrame(unmasker("football is a [MASK] game."))
# Out:
#       score  token    token_str                         sequence
# 0  0.121158   2759      popular      football is a popular game.
# 1  0.047058   2374     football     football is a football game.
# 2  0.036049   2998       sports       football is a sports game.
# 3  0.035100   2136         team         football is a team game.
# 4  0.022182   6975  competitive  football is a competitive game.

# %% [markdown]
# ### zero shot classification

# %%
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# %%
sequence_to_classify = "one day I will see the world"
candidate_labels = ['travel', 'cooking', 'dancing', 'playing', 'exploring']

# %%
pd.DataFrame(classifier(sequence_to_classify, candidate_labels))
# Out:
#                        sequence     labels    scores
# 0  one day I will see the world     travel  0.762410
# 1  one day I will see the world  exploring  0.206901
# 2  one day I will see the world    playing  0.025983
# 3  one day I will see the world    dancing  0.002511
# 4  one day I will see the world    cooking  0.002195

# %% [markdown]
# ## Important benchmarks
#
# - ***GLUE*** (General Language Understanding Evalution)
#
# - ***SuperGLUE***
#
# - ***XTREME*** (Cross-lingual TRansfer
# Evaluation of Multilingual Encoders)
#
# - ***XGLUE***
#
# - ***SQuAD***(Stanford Question Answering
# Dataset)

# %% [markdown]
# ## Working with_Datasets Libary

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 10.3 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
# download the cola dataset from the GLUE benchmark
cola = load_dataset('glue', 'cola')
# Out:
# ...
# Generating test split:   0%|          | 0/1063 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/cola/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
cola
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 8551
#     })
#     validation: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 1043
#     })
#     test: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 1063
#     })
# })

# %%
import pandas as pd
pd.DataFrame(cola['train'][:5])
# Out:
#                                             sentence  label  idx
# 0  Our friends won't buy this analysis, let alone...      1    0
# 1  One more pseudo generalization and I'm giving up.      1    1
# 2   One more pseudo generalization or I'm giving up.      1    2
# 3     The more we study verbs, the crazier they get.      1    3
# 4          Day by day the facts are getting murkier.      1    4

# %% [markdown]
# ## Metadata of Datasets:
# - ### split
# - ### description
# - ### citation
# - ### homepage
# - ### license
# - ### info

# %%
print(cola["train"].split)
print(cola["train"].description)
print(cola["train"].citation)
print(cola["train"].homepage)
print(cola["train"].license)
# Out:
# train
# GLUE, the General Language Understanding Evaluation benchmark
# (https://gluebenchmark.com/) is a collection of resources for training,
# evaluating, and analyzing natural language understanding systems.
#
#
# @article{warstadt2018neural,
#   title={Neural Network Acceptability Judgments},
#   author={Warstadt, Alex and Singh, Amanpreet and Bowman, Samuel R},
#   journal={arXiv preprint arXiv:1805.12471},
#   year={2018}
# }
# @inproceedings{wang2019glue,
#   title={{GLUE}: A Multi-Task Benchmark and Analysis Platform for Natural Language Understanding},
#   author={Wang, Alex and Singh, Amanpreet and Michael, Julian and Hill, Felix and Levy, Omer and Bowman, Samuel R.},
#   note={In the Proceedings of ICLR.},
#   year={2019}
# }
#
# https://nyu-mll.github.io/CoLA/

# %% [markdown]
# ## Explore Other Datasets :

# %%
sst2 = load_dataset('glue', 'sst2')
sst2
# Out:
# WARNING:datasets.builder:Found cached dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 872
#     })
#     test: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 1821
#     })
# })

# %%
mrpc = load_dataset('glue', 'mrpc')
mrpc
# Out:
# ...
# Generating test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/mrpc/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 3668
#     })
#     validation: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 408
#     })
#     test: Dataset({
#         features: ['sentence1', 'sentence2', 'label', 'idx'],
#         num_rows: 1725
#     })
# })

# %% [markdown]
# glue=['cola', 'sst2', 'mrpc', 'qqp', 'stsb', 'mnli', 'mnli_mismatched', 'mnli_matched', 'qnli', 'rte', 'wnli', 'ax']

# %% [markdown]
# ## Selecting, sorting, filtering

# %% [markdown]
# ## Dataset Filter and Map Function

# %% [markdown]
# ## Working with Local Files
